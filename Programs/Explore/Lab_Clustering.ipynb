# %%
import numpy as np
import pandas as pd
from collections import Counter
import re
import string
import operator


from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer 
from nltk import edit_distance


from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

lemmatizer = WordNetLemmatizer()

# %% [markdown]
# # Util

# %%
# import word2vec
word2vec = {}
with open('glove.6B.300d.txt', encoding='utf-8') as f:
    for line in f:
        try :
            values = line.split()
            word = values[0]
            vec = np.asarray(values[1:], dtype='float32')
            word2vec[word] = vec
        except :
            None

# %%
# Vectorize strings
def vectorize(s):
    v = np.zeros(300, dtype='float32')
    l = 0
    toks = word_tokenize(s)
    for w in toks :
        try :
            v += word2vec[w]
            l += 1
        except :
            print(w)
            # print words not found in glove 6B
    if l != 0 :
        return v/l
    else :
        return None

# %%
# distance btwn a word cat and an aspect (the name of the word is cat because 
#    I mostly use this function to find aspect that contains the name of the category)
def dist(cat, aspect):
    cat_ = lemmatizer.lemmatize(cat)
    toks = word_tokenize(aspect)
    l = []
    for w in toks :
        l.append(edit_distance(lemmatizer.lemmatize(w),cat_))
    return min(l)

# %%
# function to clean strings (remove stop words and keep only letters)
stop_words=set(stopwords.words("english")+list(string.punctuation)+['``',"''"]+["]","["]+['doe', 'ha', 'wa'])
def clean(s):
    return " ".join([re.sub('[^a-zA-Z]+', '', w) for w in word_tokenize(s) if not w in stop_words]).lower()

# %% [markdown]
# # Import data

# %%
df = pd.read_csv('product_aspects_electronics_and_games.csv')

# %%
df['cats'] = df.apply(lambda x : re.sub('[^a-zA-Z& ]+', '', x['cats']), axis = 1 )
df['indiv_aspects_l'] = df.apply(lambda x : [s[1:-1] for s in x['indiv_aspects'][1:-1].split(", ")], axis=1)

# I focus here on toys & games category
df = df[df['cats'] == 'Toys & Games'].copy()

# %%
# Create a list of all aspects in the dataset (this code is ugly haha...)
l_a = np.concatenate(df['indiv_aspects_l'].values)
l_a_ = [clean(x) for x in l_a]
l_a__ = [clean(x) for x in l_a_ if x!='']
aspects = [x for x in l_a__ if x!='']

set_aspects = set([x for x in l_a__ if x!=''])
count_a = Counter(aspects)
sorted_a = sorted(count_a.items(), key=operator.itemgetter(1), reverse=True)

# %%
# aspects with frequencies
sorted_a
# Out:
# [('game', 1129),
#  ('fun', 737),
#  ('great', 553),
#  ('easy', 359),
#  ('worth', 319),
#  ('good', 295),
#  ('simple', 288),
#  ('rules', 269),
#  ('cards', 248),
#  ('cute', 210),
#  ('book', 183),
#  ('nice', 178),
#  ('hard', 149),
#  ('different', 146),
#  ('small', 140),
#  ('easy learn', 135),
#  ('better', 133),
#  ('awesome', 127),
#  ('difficult', 111),
#  ('complicated', 106),
#  ('perfect', 103),
#  ('complex', 102),
#  ('lot', 100),
#  ('interesting', 97),
#  ('durable', 92),
#  ('board', 88),
#  ('elf', 83),
#  ('everyone', 81),
#  ('one', 81),
#  ('clear', 79),
#  ('beautiful', 77),
#  ('amazing', 76),
#  ('artwork', 70),
#  ('funny', 70),
#  ('quality', 70),
#  ('wonderful', 69),
#  ('cool', 68),
#  ('sturdy', 66),
#  ('adorable', 66),
#  ('players', 66),
#  ('great time', 64),
#  ('fantastic', 64),
#  ('game play', 63),
#  ('similar', 63),
#  ('excellent', 63),
#  ('instructions', 62),
#  ('enjoyable', 61),
#  ('pieces', 60),
#  ('challenging', 60),
#  ('bad', 60),
#  ('art', 59),
#  ('smaller', 58),
#  ('price', 57),
#  ('kids', 57),
#  ('possible', 56),
#  ('high', 55),
#  ('much fun', 55),
#  ('box', 51),
#  ('fine', 50),
#  ('doll', 50),
#  ('long', 50),
#  ('product', 48),
#  ('important', 48),
#  ('characters', 46),
#  ('story', 45),
#  ('quick', 45),
#  ('big', 45),
#  ('available', 45),
#  ('expensive', 45),
#  ('blast', 43),
#  ('large', 41),
#  ('cheap', 41),
#  ('gameplay', 41),
#  ('mechanics', 40),
#  ('strategy', 39),
#  ('games', 39),
#  ('lots', 39),
#  ('straightforward', 39),
#  ('ok', 39),
#  ('exciting', 39),
#  ('idea', 39),
#  ('confusing', 38),
#  ('people', 37),
#  ('new', 37),
#  ('fast', 37),
#  ('easier', 36),
#  ('easy understand', 36),
#  ('educational', 36),
#  ('balanced', 36),
#  ('questions', 35),
#  ('soft', 34),
#  ('excited', 34),
#  ('old', 34),
#  ('unique', 34),
#  ('colorful', 33),
#  ('entertaining', 33),
#  ('concept', 33),
#  ('thick', 32),
#  ('creative', 32),
#  ('full', 32),
#  ('flexible', 32),
#  ('best', 32),
#  ('detailed', 32),
#  ('happy', 30),
#  ('pictures', 30),
#  ('impossible', 30),
#  ('random', 30),
#  ('hilarious', 29),
#  ('expansion', 29),
#  ('helpful', 29),
#  ('okay', 28),
#  ('easy play', 28),
#  ('competitive', 28),
#  ('tough', 28),
#  ('components', 28),
#  ('bigger', 28),
#  ('short', 27),
#  ('directions', 27),
#  ('familiar', 27),
#  ('much', 27),
#  ('amusing', 27),
#  ('easy follow', 26),
#  ('illustrations', 26),
#  ('gorgeous', 26),
#  ('solid', 26),
#  ('toy', 26),
#  ('books', 26),
#  ('game mechanics', 25),
#  ('pages', 25),
#  ('right', 25),
#  ('clever', 25),
#  ('huge', 24),
#  ('neat', 24),
#  ('every game', 24),
#  ('creepy', 24),
#  ('colors', 24),
#  ('bright', 23),
#  ('ticket', 23),
#  ('heavy', 23),
#  ('easy pick', 22),
#  ('close', 22),
#  ('learning curve', 22),
#  ('strong', 22),
#  ('children', 22),
#  ('friends', 22),
#  ('good time', 22),
#  ('tiles', 22),
#  ('useful', 22),
#  ('true', 22),
#  ('chance', 21),
#  ('friendly', 21),
#  ('thin', 20),
#  ('theme', 20),
#  ('easy use', 20),
#  ('play', 20),
#  ('frustrating', 20),
#  ('rulebook', 20),
#  ('packaging', 19),
#  ('obvious', 19),
#  ('weak', 19),
#  ('expansions', 19),
#  ('board game', 19),
#  ('disappointing', 19),
#  ('endless', 19),
#  ('game board', 19),
#  ('silly', 19),
#  ('set', 19),
#  ('wrong', 19),
#  ('brilliant', 18),
#  ('sure', 18),
#  ('version', 18),
#  ('sweet', 17),
#  ('steep', 17),
#  ('intuitive', 17),
#  ('necessary', 17),
#  ('appropriate', 17),
#  ('boring', 17),
#  ('nothing', 17),
#  ('popular', 16),
#  ('plastic', 16),
#  ('complete', 16),
#  ('monsters', 16),
#  ('flimsy', 16),
#  ('rule book', 16),
#  ('cheaper', 16),
#  ('company', 16),
#  ('family', 16),
#  ('replay value', 16),
#  ('awful', 16),
#  ('shipping', 16),
#  ('larger', 16),
#  ('low', 15),
#  ('ability', 15),
#  ('unclear', 15),
#  ('letters', 15),
#  ('none', 15),
#  ('impressive', 15),
#  ('powerful', 14),
#  ('rare', 14),
#  ('dead', 14),
#  ('suitable', 14),
#  ('accurate', 14),
#  ('terrible', 14),
#  ('possibilities', 14),
#  ('engaging', 14),
#  ('reasonable', 14),
#  ('player', 14),
#  ('kit', 14),
#  ('pretty', 14),
#  ('useless', 13),
#  ('number', 13),
#  ('adults', 13),
#  ('time', 13),
#  ('new characters', 13),
#  ('incredible', 13),
#  ('deep', 13),
#  ('difficult understand', 13),
#  ('tiny', 13),
#  ('attractive', 13),
#  ('playable', 13),
#  ('tokens', 12),
#  ('young', 12),
#  ('tight', 12),
#  ('dark', 12),
#  ('premise', 12),
#  ('intense', 12),
#  ('harder', 12),
#  ('ideal', 12),
#  ('deck', 12),
#  ('involved', 12),
#  ('system', 12),
#  ('portable', 12),
#  ('cooperative', 12),
#  ('pricey', 12),
#  ('item', 12),
#  ('pleased', 12),
#  ('likely', 12),
#  ('higher', 12),
#  ('annoying', 12),
#  ('fun play', 12),
#  ('potential', 12),
#  ('strategic', 12),
#  ('less', 12),
#  ('everything', 12),
#  ('original', 12),
#  ('paced', 12),
#  ('real', 11),
#  ('crazy', 11),
#  ('quick learn', 11),
#  ('addictive', 11),
#  ('anyone', 11),
#  ('combat', 11),
#  ('outstanding', 11),
#  ('others', 11),
#  ('glad', 11),
#  ('replayability', 11),
#  ('unbalanced', 11),
#  ('problems', 11),
#  ('elegant', 11),
#  ('numbers', 11),
#  ('disappointed', 11),
#  ('superior', 10),
#  ('amount', 10),
#  ('skirt', 10),
#  ('magnets', 10),
#  ('humor', 10),
#  ('identical', 10),
#  ('things', 10),
#  ('sleeves', 10),
#  ('decent', 10),
#  ('special', 10),
#  ('ball', 10),
#  ('goal', 10),
#  ('able play', 10),
#  ('key', 10),
#  ('compatible', 10),
#  ('older', 10),
#  ('safe', 10),
#  ('equal', 10),
#  ('light', 10),
#  ('daughter', 10),
#  ('size', 9),
#  ('rich', 9),
#  ('accessible', 9),
#  ('dice', 9),
#  ('seller', 9),
#  ('visible', 9),
#  ('late', 9),
#  ('rewarding', 9),
#  ('varied', 9),
#  ('slow', 9),
#  ('compact', 9),
#  ('ridiculous', 9),
#  ('puzzle', 9),
#  ('son', 9),
#  ('problem', 9),
#  ('way', 9),
#  ('priceless', 9),
#  ('worse', 9),
#  ('heroes', 9),
#  ('customer service', 9),
#  ('parents', 9),
#  ('depth', 9),
#  ('alright', 9),
#  ('tedious', 9),
#  ('great fun', 9),
#  ('lovely', 9),
#  ('tricky', 9),
#  ('present', 9),
#  ('blocks', 8),
#  ('welcome', 8),
#  ('vague', 8),
#  ('overpriced', 8),
#  ('text', 8),
#  ('plenty', 8),
#  ('person', 8),
#  ('option', 8),
#  ('novel', 8),
#  ('basic', 8),
#  ('card game', 8),
#  ('trouble', 8),
#  ('setup', 8),
#  ('interested', 8),
#  ('map', 8),
#  ('ton', 8),
#  ('zombies', 8),
#  ('prompt', 8),
#  ('white', 8),
#  ('common', 8),
#  ('tons', 8),
#  ('enough', 8),
#  ('addition', 8),
#  ('dependent', 8),
#  ('smooth', 8),
#  ('money', 8),
#  ('puppet', 8),
#  ('bent', 8),
#  ('quick play', 8),
#  ('child', 8),
#  ('advantage', 8),
#  ('part', 8),
#  ('simple learn', 8),
#  ('figures', 8),
#  ('cumbersome', 7),
#  ('complexity', 7),
#  ('reviews', 7),
#  ('surprised', 7),
#  ('game night', 7),
#  ('satisfying', 7),
#  ('interactive', 7),
#  ('one player', 7),
#  ('nicer', 7),
#  ('bit', 7),
#  ('essential', 7),
#  ('exceptional', 7),
#  ('stupid', 7),
#  ('art work', 7),
#  ('difficulty', 7),
#  ('object', 7),
#  ('fragile', 7),
#  ('incomplete', 7),
#  ('limited', 7),
#  ('odd', 7),
#  ('bookmark', 7),
#  ('thing', 7),
#  ('fabulous', 7),
#  ('something', 7),
#  ('versatile', 7),
#  ('busy', 7),
#  ('intriguing', 7),
#  ('sad', 7),
#  ('paper', 7),
#  ('alot', 7),
#  ('images', 7),
#  ('horrible', 7),
#  ('stronger', 7),
#  ('terrific', 7),
#  ('naughty', 7),
#  ('pleasing', 7),
#  ('easy set', 7),
#  ('alive', 7),
#  ('hard find', 7),
#  ('superb', 7),
#  ('rest', 7),
#  ('able', 7),
#  ('ready', 7),
#  ('opportunity', 7),
#  ('races', 7),
#  ('easy read', 7),
#  ('couple', 7),
#  ('black', 6),
#  ('character', 6),
#  ('process', 6),
#  ('correct', 6),
#  ('suited', 6),
#  ('card', 6),
#  ('picture', 6),
#  ('fair', 6),
#  ('mediocre', 6),
#  ('loose', 6),
#  ('turn', 6),
#  ('simpler', 6),
#  ('pack', 6),
#  ('open', 6),
#  ('website', 6),
#  ('rule', 6),
#  ('anything', 6),
#  ('sound', 6),
#  ('quotes', 6),
#  ('slippery', 6),
#  ('brutal', 6),
#  ('stickers', 6),
#  ('weaknesses', 6),
#  ('index', 6),
#  ('quests', 6),
#  ('poor', 6),
#  ('materials', 6),
#  ('lengthy', 6),
#  ('classes', 6),
#  ('informative', 6),
#  ('easy grasp', 6),
#  ('days', 6),
#  ('scenarios', 6),
#  ('ships', 6),
#  ('plush', 6),
#  ('worthwhile', 6),
#  ('subtle', 6),
#  ('overwhelming', 6),
#  ('package', 6),
#  ('decks', 6),
#  ('lower', 6),
#  ('miniatures', 6),
#  ('symbols', 6),
#  ('spot', 6),
#  ('scary', 6),
#  ('younger', 6),
#  ('game components', 6),
#  ('elves', 6),
#  ('proud', 6),
#  ('thematic', 6),
#  ('timer', 6),
#  ('feel', 6),
#  ('reminiscent', 6),
#  ('print', 6),
#  ('simple play', 6),
#  ('humorous', 6),
#  ('scoring', 6),
#  ('longer', 6),
#  ('dull', 6),
#  ('quite bit', 6),
#  ('effective', 6),
#  ('content', 6),
#  ('game system', 6),
#  ('manageable', 6),
#  ('usable', 6),
#  ('base game', 6),
#  ('difficult learn', 6),
#  ('balance', 6),
#  ('group', 6),
#  ('able get', 6),
#  ('hours', 6),
#  ('boy', 6),
#  ('flavor', 6),
#  ('board games', 6),
#  ('answers', 5),
#  ('game pieces', 5),
#  ('cover', 5),
#  ('clothes', 5),
#  ('dynamic', 5),
#  ('production values', 5),
#  ('topics', 5),
#  ('misleading', 5),
#  ('advanced', 5),
#  ('lame', 5),
#  ('fun time', 5),
#  ('flat', 5),
#  ('quicker', 5),
#  ('color', 5),
#  ('types', 5),
#  ('photos', 5),
#  ('successful', 5),
#  ('variety', 5),
#  ('predictable', 5),
#  ('easy shuffle', 5),
#  ('playing cards', 5),
#  ('sets', 5),
#  ('length', 5),
#  ('activities', 5),
#  ('flawed', 5),
#  ('professional', 5),
#  ('writing', 5),
#  ('pleasant', 5),
#  ('experience', 5),
#  ('easy get', 5),
#  ('affordable', 5),
#  ('quirky', 5),
#  ('lucky', 5),
#  ('afraid', 5),
#  ('phenomenal', 5),
#  ('inexpensive', 5),
#  ('removable', 5),
#  ('choice', 5),
#  ('bulky', 5),
#  ('tense', 5),
#  ('hard learn', 5),
#  ('consistent', 5),
#  ('dry', 5),
#  ('diary', 5),
#  ('careful', 5),
#  ('mechanic', 5),
#  ('whole idea', 5),
#  ('crucial', 5),
#  ('magical', 5),
#  ('hard get', 5),
#  ('cost', 5),
#  ('ones', 5),
#  ('convenient', 5),
#  ('kind', 5),
#  ('options', 5),
#  ('complicated learn', 5),
#  ('hard turn', 5),
#  ('parts', 5),
#  ('production value', 5),
#  ('easy teach', 5),
#  ('titles', 5),
#  ('easy win', 5),
#  ('quick set', 5),
#  ('faster', 5),
#  ('clunky', 5),
#  ('organized', 5),
#  ('loads', 5),
#  ('grandchildren', 5),
#  ('basic rules', 5),
#  ('ideas', 5),
#  ('bored', 5),
#  ('charming', 5),
#  ('name', 5),
#  ('setting', 5),
#  ('combat system', 5),
#  ('hard understand', 5),
#  ('hard time', 5),
#  ('intricate', 5),
#  ('asleep', 5),
#  ('bunch', 5),
#  ('card quality', 5),
#  ('ways', 5),
#  ('satisfied', 5),
#  ('witty', 5),
#  ('addicting', 5),
#  ('colored', 5),
#  ('spaces', 5),
#  ('simplistic', 5),
#  ('concepts', 4),
#  ('turns', 4),
#  ('green', 4),
#  ('strange', 4),
#  ('playing pieces', 4),
#  ('delighted', 4),
#  ('generic', 4),
#  ('delicate', 4),
#  ('negative', 4),
#  ('attention', 4),
#  ('winner', 4),
#  ('design', 4),
#  ('cardboard', 4),
#  ('calendar', 4),
#  ('diverse', 4),
#  ('responsive', 4),
#  ('effect', 4),
#  ('hard shuffle', 4),
#  ('inappropriate', 4),
#  ('folks', 4),
#  ('excitement', 4),
#  ('review', 4),
#  ('venerable consider', 4),
#  ('second', 4),
#  ('educational value', 4),
#  ('overwhelmed', 4),
#  ('serious', 4),
#  ('half', 4),
#  ('weapons', 4),
#  ('square', 4),
#  ('issue', 4),
#  ('action cards', 4),
#  ('sturdier', 4),
#  ('sense', 4),
#  ('backs', 4),
#  ('favorite', 4),
#  ('fact', 4),
#  ('willing', 4),
#  ('many options', 4),
#  ('hard use', 4),
#  ('free', 4),
#  ('excited see', 4),
#  ('minimal', 4),
#  ('value', 4),
#  ('unnecessary', 4),
#  ('decisions', 4),
#  ('rewards', 4),
#  ('flavor text', 4),
#  ('delivery', 4),
#  ('ambiguous', 4),
#  ('clearer', 4),
#  ('layout', 4),
#  ('papers', 4),
#  ('gathering', 4),
#  ('abstract', 4),
#  ('back', 4),
#  ('ugly', 4),
#  ('separate', 4),
#  ('customizable', 4),
#  ('transparent', 4),
#  ('battles', 4),
#  ('ordering', 4),
#  ('unbeatable', 4),
#  ('easy master', 4),
#  ('difficult master', 4),
#  ('places', 4),
#  ('detail', 4),
#  ('little elf', 4),
#  ('weird', 4),
#  ('abilities', 4),
#  ('compelling', 4),
#  ('stories', 4),
#  ('finished product', 4),
#  ('amazed', 4),
#  ('every player', 4),
#  ('space', 4),
#  ('core set', 4),
#  ('brief', 4),
#  ('sick', 4),
#  ('one person', 4),
#  ('place', 4),
#  ('unlikely', 4),
#  ('humans', 4),
#  ('issues', 4),
#  ('names', 4),
#  ('nasty', 4),
#  ('sad see', 4),
#  ('new players', 4),
#  ('outcome', 4),
#  ('empty', 4),
#  ('lock', 4),
#  ('photo', 4),
#  ('unpredictable', 4),
#  ('special abilities', 4),
#  ('hands', 4),
#  ('thicker', 4),
#  ('casual', 4),
#  ('fit', 4),
#  ('construction', 4),
#  ('adventure', 4),
#  ('stats', 4),
#  ('daunting', 4),
#  ('manual', 4),
#  ('thinner', 4),
#  ('point', 4),
#  ('dangerous', 4),
#  ('influence', 4),
#  ('powers', 4),
#  ('info', 4),
#  ('author', 4),
#  ('photographs', 4),
#  ('skill', 4),
#  ('areas', 4),
#  ('crisp', 4),
#  ('vibrant', 4),
#  ('minutes', 4),
#  ('look', 4),
#  ('animals', 4),
#  ('plush toy', 4),
#  ('tall', 4),
#  ('many games', 4),
#  ('front', 4),
#  ('little', 4),
#  ('enemies', 4),
#  ('damage', 4),
#  ('several', 4),
#  ('practical', 4),
#  ('level', 4),
#  ('traitor', 4),
#  ('graphics', 4),
#  ('hard figure', 4),
#  ('friend', 4),
#  ('expansion pack', 4),
#  ('trains', 4),
#  ('efficient', 3),
#  ('positive', 3),
#  ('stunning', 3),
#  ('coloring book', 3),
#  ('bendable', 3),
#  ('many', 3),
#  ('easy find', 3),
#  ('words', 3),
#  ('experienced players', 3),
#  ('game box', 3),
#  ('special cards', 3),
#  ('holes', 3),
#  ('life', 3),
#  ('enormous', 3),
#  ('readable', 3),
#  ('dimensional', 3),
#  ('evocative', 3),
#  ('player games', 3),
#  ('every card', 3),
#  ('slots', 3),
#  ('younger ones', 3),
#  ('hysterical', 3),
#  ('evil', 3),
#  ('big fit', 3),
#  ('effects', 3),
#  ('body', 3),
#  ('simple teach', 3),
#  ('corners', 3),
#  ('features', 3),
#  ('textures', 3),
#  ('teams', 3),
#  ('kid', 3),
#  ('imaginative', 3),
#  ('slower', 3),
#  ('sided', 3),
#  ('style', 3),
#  ('patient', 3),
#  ('upset', 3),
#  ('explanatory', 3),
#  ('immersive', 3),
#  ('able enjoy', 3),
#  ('lackluster', 3),
#  ('softer', 3),
#  ('minor', 3),
#  ('blue', 3),
#  ('active', 3),
#  ('repetitive', 3),
#  ('insane', 3),
#  ('boards', 3),
#  ('instruction booklet', 3),
#  ('expandable', 3),
#  ('routes', 3),
#  ('able take', 3),
#  ('aware', 3),
#  ('batteries', 3),
#  ('easy figure', 3),
#  ('everybody', 3),
#  ('velcro', 3),
#  ('epic', 3),
#  ('two people', 3),
#  ('memorable', 3),
#  ('enough strategy', 3),
#  ('fascinating', 3),
#  ('first thing', 3),
#  ('power', 3),
#  ('reaction', 3),
#  ('concise', 3),
#  ('comprehensive', 3),
#  ('actions', 3),
#  ('stencils', 3),
#  ('defective', 3),
#  ('marker', 3),
#  ('elements', 3),
#  ('huge amount', 3),
#  ('gifts', 3),
#  ('difficult follow', 3),
#  ('different abilities', 3),
#  ('steep learning curve', 3),
#  ('scores', 3),
#  ('strategies', 3),
#  ('cartoonish', 3),
#  ('teachers', 3),
#  ('girls', 3),
#  ('hard read', 3),
#  ('phases', 3),
#  ('sharp', 3),
#  ('shiny', 3),
#  ('supplies', 3),
#  ('fresh', 3),
#  ('rounds', 3),
#  ('squares', 3),
#  ('chaotic', 3),
#  ('items', 3),
#  ('game design', 3),
#  ('impact', 3),
#  ('tracks', 3),
#  ('case', 3),
#  ('great theme', 3),
#  ('cardboard pieces', 3),
#  ('fantastic time', 3),
#  ('blast playing', 3),
#  ('willing play', 3),
#  ('worried', 3),
#  ('points', 3),
#  ('overlord', 3),
#  ('rough', 3),
#  ('results', 3),
#  ('battery', 3),
#  ('variable', 3),
#  ('shorter', 3),
#  ('missions', 3),
#  ('competition', 3),
#  ('expansion packs', 3),
#  ('whole thing', 3),
#  ('action', 3),
#  ('two games', 3),
#  ('older kids', 3),
#  ('easy pickup', 3),
#  ('easier learn', 3),
#  ('legal', 3),
#  ('flavorful', 3),
#  ('guys', 3),
#  ('doable', 3),
#  ('luck', 3),
#  ('planets', 3),
#  ('room', 3),
#  ('feet', 3),
#  ('smart', 3),
#  ('reputation', 3),
#  ('vivid', 3),
#  ('replayable', 3),
#  ('wide', 3),
#  ('bear', 3),
#  ('drawings', 3),
#  ('service', 3),
#  ('description', 3),
#  ('bits', 3),
#  ('order', 3),
#  ('train', 3),
#  ('loud', 3),
#  ('tactical', 3),
#  ('easy make', 3),
#  ('final product', 3),
#  ('element', 3),
#  ('slick', 3),
#  ('dolls', 3),
#  ('cylons', 3),
#  ('crafty', 3),
#  ('many rules', 3),
#  ('intact', 3),
#  ('hand', 3),
#  ('response', 3),
#  ('tunnels', 3),
#  ('beads', 3),
#  ('versions', 3),
#  ('sized', 3),
#  ('page', 3),
#  ('awkward', 3),
#  ('whole concept', 3),
#  ('thorough', 3),
#  ('comfortable', 3),
#  ('clean', 3),
#  ('geared', 3),
#  ('easy see', 3),
#  ('inventive', 3),
#  ('aggressive', 3),
#  ('magic', 3),
#  ('type', 3),
#  ('easy carry', 3),
#  ('red', 3),
#  ('printing quality', 3),
#  ('record', 3),
#  ('expansion sets', 3),
#  ('impressed', 3),
#  ('year old son', 3),
#  ('functional', 3),
#  ('pockets', 3),
#  ('little bit', 3),
#  ('beneficial', 3),
#  ('use', 3),
#  ('ingenious', 3),
#  ('plain', 3),
#  ('overall quality', 3),
#  ('particular set', 3),
#  ('easy explain', 3),
#  ('great potential', 3),
#  ('guy', 3),
#  ('easier play', 3),
#  ('mirror', 3),
#  ('gold', 3),
#  ('messy', 3),
#  ('sooo', 3),
#  ('spectacular', 3),
#  ('massive', 3),
#  ('touch', 3),
#  ('transparent cards', 3),
#  ('delightful', 3),
#  ('personal', 3),
#  ('high replay value', 3),
#  ('unfortunate', 3),
#  ('events', 3),
#  ('story line', 3),
#  ('bland', 3),
#  ('edition', 3),
#  ('pics', 3),
#  ('baby', 3),
#  ('costly', 3),
#  ('tired', 3),
#  ('resources', 3),
#  ('applicable', 3),
#  ('mat', 3),
#  ('graphic design', 3),
#  ('citadels', 3),
#  ('creators', 3),
#  ('game cards', 3),
#  ('small cards', 3),
#  ('regions', 3),
#  ('sides', 3),
#  ('production', 3),
#  ('excited find', 3),
#  ('pathetic', 3),
#  ('storybook', 3),
#  ('strategy aspect', 2),
#  ('good replay value', 2),
#  ('original game', 2),
#  ('capable', 2),
#  ('husband', 2),
#  ('potent', 2),
#  ('magic items', 2),
#  ('alone', 2),
#  ('disadvantages', 2),
#  ('apparent', 2),
#  ('miserable', 2),
#  ('happiness', 2),
#  ('repetitious', 2),
#  ('feeling', 2),
#  ('cons', 2),
#  ('collection', 2),
#  ('long make', 2),
#  ('letter tiles', 2),
#  ('plastic pieces', 2),
#  ('adventure cards', 2),
#  ('nativity advent calendar', 2),
#  ('able read', 2),
#  ('best prices', 2),
#  ('able keep', 2),
#  ('production quality', 2),
#  ('drunk', 2),
#  ('fabric', 2),
#  ('illustory', 2),
#  ('good sense', 2),
#  ('mom', 2),
#  ('notes', 2),
#  ('workbook', 2),
#  ('dumb', 2),
#  ('extensive', 2),
#  ('skeptical', 2),
#  ('lacking', 2),
#  ('wonderful time', 2),
#  ('super', 2),
#  ('puppets', 2),
#  ('made', 2),
#  ('stale', 2),
#  ('wait', 2),
#  ('two players', 2),
#  ('crayons', 2),
#  ('worthy', 2),
#  ('model', 2),
#  ('ended', 2),
#  ('train cards', 2),
#  ('easier use', 2),
#  ('much trouble', 2),
#  ('core gameplay', 2),
#  ('execution', 2),
#  ('dramatic', 2),
#  ('price tag', 2),
#  ('first', 2),
#  ('complicated play', 2),
#  ('plot', 2),
#  ('minis', 2),
#  ('gimmicky', 2),
#  ('stuffed animal', 2),
#  ('robust', 2),
#  ('rigid', 2),
#  ('track', 2),
#  ('much luck', 2),
#  ('expensive keep', 2),
#  ('soundtrack', 2),
#  ('jabs', 2),
#  ('enemy', 2),
#  ('play time', 2),
#  ('strengths', 2),
#  ('worthless', 2),
#  ('best price', 2),
#  ('remarkable', 2),
#  ('female', 2),
#  ('able come', 2),
#  ('core game', 2),
#  ('average', 2),
#  ('cat', 2),
#  ('glossy', 2),
#  ('hard win', 2),
#  ('face', 2),
#  ('deceptive', 2),
#  ('social skills', 2),
#  ('many pages', 2),
#  ('game game', 2),
#  ('advantages', 2),
#  ('interesting play', 2),
#  ('examples', 2),
#  ('relatives', 2),
#  ('thoughtful', 2),
#  ('shadows', 2),
#  ('great sense', 2),
#  ...]

# %% [markdown]
# # vectorize aspects

# %%
L = []
X = []
idx = []
for a in set_aspects:
    v_ = vectorize(a)
    if (type(v_) !=  type(None))&(dist('game', a) != 0) :
        # I remove the aspects that containts the word "game"
        L.append(('games', (a, count_a[a] ,v_)))
        X.append(v_)
        idx.append(a)
# the prints are the words not found in glove 6B -> could be improve by adding a spacy corrector
# Out:
# humungous
# granparents
# genestealers
# spendy
# vaue
# artworkcons
# toonish
# boardgamers
# manipulatable
# strengthcraft
# awsome
# perfumyplasticy
# wowfactor
# discriptions
# oldschool
# allno
# mendable
# fragileish
# slaphappy
# magnifacant
# gamebox
# metallicpearled
# immediatesatisfaction
# levals
# beatiful
# georgeous
# faceup
# easilymastered
# positionable
# lesserskilled
# peices
# deckbuilding
# gofish
# interestingfun
# titlevillain
# injokes
# moviegame
# minitures
# appearent
# twowagon
# playabilty
# ironbreaker
# unstreamlined
# ffgs
# flawlessness
# catanesque
# eatch
# varities
# awardwinning
# unpredicatable
# comperable
# infantries
# motiv
# longthe
# tieins
# replayablility
# veryartistic
# pikids
# abovepar
# cardbasedfamily
# hisher
# headfacehair
# minichallenges
# wikkistix
# twopart
# gratzirachel
# madeand
# twoplayer
# paida
# lockin
# simplethe
# playerplayer
# niceweight
# expac
# reallife
# instrucion
# bookthe
# interestingwe
# erratas
# hitpoints
# liveshealth
# shinynew
# booktoy
# explanantions
# illistration
# supermag
# hillarious
# helpfull
# packable
# chanceluck
# ordable
# terraformers
# instructionsrules
# stratigy
# deckbuilding
# tournamentlegal
# detractions
# abyssmal
# mixable
# readthe
# weaponarmor
# tightfit
# kidcentric
# runewars
# rediculous
# tilelock
# greatgranddaughter
# involvedwith
# winsthe
# boomph
# boughtdunwichfirst
# prosthe
# clearcard
# sixpanel
# wizardy
# monstercreation
# untraversable
# everythin
# individualpersonalities
# tonebreaking
# yearold
# customizeable
# incosiderate
# iscastle
# replayablility
# ordance
# fullcolor
# fourletter
# comming
# adultlevel
# boook
# appearant
# repead
# questionlimit
# gamelover
# conslike
# singlerow
# soooooo
# strenght
# replayable
# easytouse
# wfrp
# competative
# squishable
# discribed
# boardcards
# strenght
# expasions
# fourday
# genestealer
# boardcard
# illustory
# constuction
# filsinger
# racebased
# manowars
# dissappointing
# staightforward
# pictureseasy
# themeconcept
# inportant
# describtion
# decksthe
# thamaturgy
# wellconstructedthe
# welldeserved
# enjoyability
# flexable
# playmat
# illistration
# vauge
# actionstragedies
# pregenerated
# phenominal
# bluffinglike
# cardsonly
# oldtimey
# seethrough
# impresive
# overpowerful
# themthe
# greeat
# eurogamers
# greggor
# halfass
# dedicaton
# scaleable
# managable
# quicklythe
# adhensive
# gifter
# puzzelations
# helpthe
# yrolds
# educatioinal

# %%
X = np.array(X)
idx = np.array(idx)
df = pd.DataFrame(data=X, index=idx)

# %% [markdown]
# # Elbow method

# %%
# Takes time to run !!!

# scores = []
# ks = []
# stds = []
# for k in range (10, 30):
#     print(k)
#     ks.append(k)
#     scores_i = []
#     for i in range (20):
#         kmeans = KMeans(n_clusters = k)
#         y_pred = kmeans.fit_predict(X)
#         score = silhouette_score(X, y_pred)
#         scores_i.append(score)
#     mean_ = np.mean(scores_i)
#     std_ = np.std(scores_i)
#     scores.append(mean_)
#     stds.append(std_)
#     print (mean_, std_)

# %%
# scores_up = np.array(scores)+3*np.array(stds)
# scores_down = np.array(scores)-3*np.array(stds)

# %%
# plt.plot(ks, scores)
# plt.plot(ks, scores_up)
# plt.plot(ks, scores_down)

# the plot is not very nice...

# %%
# nb_cluster_opti = ks[np.argmin(scores)]
nb_cluster_opti = 14
nb_cluster_opti
# Out:
# 14

# %% [markdown]
# # Fit Kmean with optimal k

# %%
kmeans = KMeans(n_clusters = nb_cluster_opti, random_state=0).fit(X)
centers = kmeans.cluster_centers_
df['cluster'] = kmeans.labels_

# %%
# take aspects close to each centroid to represent the cluster
clusters = {}
for i in range (nb_cluster_opti):
    df_i = df[df['cluster']==i].copy()
    arr_i = df_i.values[:,:-1]
    c = centers[i]
    df_i['dist'] = np.apply_along_axis(lambda x : np.sqrt(np.sum((x-c)**2)), 1, arr_i)
    idx_close = list(df_i['dist'].sort_values()[:10].index)
    clusters[i] = idx_close

# %%
clusters
# Out:
# {0: ['well many way',
#   'way many rules',
#   'particular set',
#   'much various things',
#   'instance',
#   'one particular suspect',
#   'way many advantages',
#   'way many pieces',
#   'several small expansion packs',
#   'many moves'],
#  1: ['fate point economy epiphany',
#   'likely experience',
#   'subtle long term effects',
#   'pretty much effects',
#   'three builtin difficulty levels',
#   'major annoying differences',
#   'much leadership synergy',
#   'luck risk element',
#   'wound success markers',
#   'fact'],
#  2: ['unique ruinous power cultist figures staves',
#   'lastly heroes',
#   'dark tales expansion pack',
#   'crafty original dice mechanic',
#   'even weakest mages',
#   'warlock quest cards',
#   'zombie survivor pieces',
#   'childrens first instinct',
#   'firefly universe money',
#   'rafter several unsuccessful guesses'],
#  3: ['one practice round',
#   'least one new person',
#   'first thing',
#   'next day perfect condition',
#   'last one',
#   'one set',
#   'first one',
#   'first time',
#   'every expansion set',
#   'single goal stop bad things'],
#  4: ['even cards',
#   'similar cards',
#   'certain cards',
#   'clear cards',
#   'one card',
#   'end cards',
#   'two simple cards',
#   'couple cards',
#   'little cards',
#   'many cards'],
#  5: ['even better time christmas time fun',
#   'really fun time',
#   'much word still fun',
#   'fun getting look',
#   'nice big puzzle well made box',
#   'really good time',
#   'good fun attention',
#   'many fantastic cute ideas',
#   'even bad idea',
#   'wonderful time'],
#  6: ['even turn handle',
#   'able come',
#   'easy put',
#   'difficult turn',
#   'difficult put',
#   'easy take',
#   'able make',
#   'easy turn',
#   'able figured',
#   'impossible take'],
#  7: ['neither small cardboard item tokens',
#   'clear plastic penguin pieces',
#   'well designed box insert',
#   'little plastic cast figurines',
#   'monochromatic gray plastic figurines',
#   'high quality wooden bits cards',
#   'nice raised textured pattern',
#   'small cardboard circle',
#   'nice plastic pieces',
#   'many cardboard pieces'],
#  8: ['forthe original citadels',
#   'pitiful mortal denizens',
#   'orc wich',
#   'random awesomeness',
#   'fav pony',
#   'catacomb deviation',
#   'whatnot',
#   'pixie enchanter',
#   'repeat playability',
#   'constant recalculating'],
#  9: ['drop component quality',
#   'lot higher replay value',
#   'much less efficient kingdom deck',
#   'rather large amount',
#   'high quality pieces cards',
#   'price time limit',
#   'less perfect packaging',
#   'much larger reward',
#   'fantastic overall production quality',
#   'good amount'],
#  10: ['amazing setting creation system excellent characters',
#   'interesting attack resource building mechanics',
#   'therefore different strengths',
#   'much different premise',
#   'simple fun strategic concept',
#   'unique way',
#   'rather unique gameplay',
#   'even vocabulary requirements',
#   'different skill sets',
#   'additional complicated elements'],
#  11: ['even artwork',
#   'working portable tape player menu guidelines',
#   'hard cover book',
#   'first time deluxe version',
#   'different back artwork',
#   'simple creative story line',
#   'another homework book',
#   'read touch books',
#   'many beautiful christmas books',
#   'much beautiful artwork'],
#  12: ['whatever inane spinoff',
#   'problematic',
#   'hesitant reveal',
#   'lazy undo',
#   'superfluous',
#   'trickier city layouts',
#   'laughable',
#   'prone bumped',
#   'infuriating',
#   'uninteresting'],
#  13: ['great illustrations adorable direction',
#   'funny likeable experience',
#   'brilliant munchkin humor',
#   'joke milieu',
#   'fun textures',
#   'silly weird events',
#   'fun premise',
#   'interesting quirks',
#   'negative creepy vibe',
#   'hilarious watch']}

# %% [markdown]
# # Lab

# %%
# print the aspects that contains game we could keep these aspect and just remove the word "game" from the aspects !
dict_dist = {a : dist('game', a) for a in set_aspects}
for x in dict_dist :
    if dict_dist[x] == 0 :
        print(x)
# Out:
# unique game play
# board game variation
# mind games
# word game
# times game
# x matrix game
# excellent game
# wanted game
# strategy card game
# ps video games
# overall game
# clever homogenous game design
# old scrabble game
# new game system
# game mechanics
# close game
# another fantasy flight game
# weekly game night
# card games
# original game
# every game
# game experience
# game nights
# complex game
# person games
# many cool board games
# well thought game system
# basic game functions
# several wrestling games
# one practice game
# game learning curve
# complexity game length
# riotous game
# twoplayer game
# good game play
# classic game
# game board art
# game
# game adaptations
# competitive game
# game design
# team building games
# geography game
# board game version
# first games
# quicklythe game pieces
# many trading card games
# party game
# game game
# regular game night
# even quickstart game
# game system
# game maker
# multiplayer games
# game manual
# game cards
# unfinished game
# interesting game
# new game
# great family game night
# many games
# four card games cases
# many frustrating game
# big boggle game
# board game
# fresh game play
# game play
# board games
# latter game
# player games
# actual game play
# almost every board game
# second game
# game card
# game world
# game board
# game construction
# one game multiple players
# true game
# several lotr games
# x boggle game
# original card game
# munchkin games
# best educational games
# pretty unattractive game board
# game artwork
# game time
# basic game
# game quality
# pickup game
# fantasy games
# game books
# ongoing scrabble game
# complex game time
# normal cad games
# difficult game
# asymmetrical game
# boardcard games
# first two three games
# latest game
# board paper games letter
# old game
# family game
# two games
# backs game
# transparent cards game mechanic
# game night
# juice video game toys
# game components
# games
# solid game mechanic
# armies game
# game scenarios
# core game
# game rules
# first game
# game pieces
# genre game
# game mechanic
# one game
# several board games
# scifi horror games
# unique game mechanic
# filsinger games
# hilarious card game
# good games
# default game
# game package
# even first game
# base game
# rummy card game
# free game scenario
# many game nights
# fun game
# good two player games
# fragile game board
# great brain game
# card game
# far superior games
# elaborate game
# good player games
# prosthe game
# five person game
# traditional games
# artwork game play
# simple games
# game wheels
# ravenloft game
# strategy games
# excellent fun game
# game box
# casual games
# wizard card game
# video game version
